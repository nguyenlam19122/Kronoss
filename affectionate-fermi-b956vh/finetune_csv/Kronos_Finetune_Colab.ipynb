# %% [markdown]
# # 🎯 Fine-tune Kronos trên dữ liệu của bạn (US30 / USTEC M30)
#
# Huấn luyện lại Kronos-small trên đúng mã của bạn để **tạo edge** mà model gốc chưa có, rồi **đo lại edge out-of-sample** so với model gốc.
#
# **Bắt buộc GPU:** Runtime → Change runtime type → **T4 GPU**. (Fine-tune trên CPU là bất khả thi.)
#
# > Quy trình: clone → cài đặt → fine-tune (tokenizer → predictor) → đo edge model mới vs gốc trên phần dữ liệu CHƯA train.

# %% [markdown]
# ## Bước 1 — Kiểm tra GPU (bắt buộc)

# %%
import torch
assert torch.cuda.is_available(), '❌ CHƯA bật GPU! Runtime > Change runtime type > T4 GPU, rồi chạy lại.'
print('✅ GPU:', torch.cuda.get_device_name(0))

# %% [markdown]
# ## Bước 2 — Tải code & cài đặt
#
# Repo đã public nên clone không cần token. Chỉ cài thêm vài thư viện Kronos cần (torch/pandas đã có sẵn trên Colab).

# %%
import os, sys
os.chdir('/content')
if not os.path.isdir('/content/Kronoss/.git'):
    # !git clone --quiet --branch claude/affectionate-fermi-b956vh https://github.com/nguyenlam19122/Kronoss.git
os.chdir('/content/Kronoss'); sys.path.insert(0, '/content/Kronoss')
# !pip install -q einops huggingface_hub safetensors pyyaml
import trading; print('✅ Sẵn sàng — cwd:', os.getcwd())

# %% [markdown]
# ## Bước 3 — Chọn mã & fine-tune
#
# Đổi `SYM` thành `US30` hoặc `USTEC`. Quá trình gồm 2 giai đoạn (tokenizer → predictor), ~30–90 phút trên T4.
#
# Config nằm ở `finetune_csv/configs/config_{SYM}_M30.yaml` (lookback 256, predict 16, train 70% / val 15% / test 15%). Muốn chỉnh epoch/learning-rate thì sửa file đó.

# %%
SYM = 'US30'   # hoặc 'USTEC'
import os
os.chdir('/content/Kronoss/finetune_csv')
# !python train_sequential.py --config configs/config_{SYM}_M30.yaml
os.chdir('/content/Kronoss')
print('Model đã fine-tune lưu ở: finetune_csv/finetuned/%s_M30/' % SYM)
# Out:
# Using device: cuda:0 (rank=0, world_size=1, local_rank=0)
# ============================================================
# Kronos finetuning configuration summary
# ============================================================
# Experiment name: US30_M30
# Data path: data/US30_M30_ft.csv
# Lookback window: 256
# Predict window: 16
# Tokenizer training epochs: 8
# Basemodel training epochs: 15
# Batch size: 32
# Tokenizer learning rate: 0.0002
# Predictor learning rate: 2e-05
# Train tokenizer: True
# Train basemodel: True
# Skip existing: False
# Use pre-trained tokenizer: True
# Use pre-trained predictor: True
# Base save path: finetuned/US30_M30
# Tokenizer save path: finetuned/US30_M30/tokenizer
# Basemodel save path: finetuned/US30_M30/basemodel
# ============================================================
# Starting Kronos model sequential fine-tuning training
# Experiment name: kronos_US30_M30_finetune
# Experiment description: Fine-tune Kronos-small on US30 M30 (indices, short-horizon)
# Distributed training not enabled, using single GPU/CPU training
# Created directory: finetuned/US30_M30/tokenizer
# Created directory: finetuned/US30_M30/basemodel
# Tokenizer model exists: True
# Basemodel model exists: True
#
# ============================================================
# Starting Tokenizer Fine-tuning Phase
# ============================================================
# Tokenizer model exists: True
# Basemodel model exists: True
# 2026-06-21 02:56:14 - tokenizer_training_rank_0 - INFO - === Tokenizer Training Started ===
# 2026-06-21 02:56:14 - tokenizer_training_rank_0 - INFO - Experiment Name: US30_M30
# 2026-06-21 02:56:14 - tokenizer_training_rank_0 - INFO - Log Directory: finetuned/US30_M30/logs
# 2026-06-21 02:56:14 - tokenizer_training_rank_0 - INFO - Rank: 0
# 2026-06-21 02:56:14 - tokenizer_training_rank_0 - INFO - Timestamp: 2026-06-21 02:56:14
# 2026-06-21 02:56:14 - tokenizer_training_rank_0 - INFO - Loading pretrained tokenizer...
# Loading pretrained tokenizer...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-06-21 02:56:14 - tokenizer_training_rank_0 - INFO - Tokenizer parameters: 3,958,042
# Tokenizer parameters: 3,958,042
# 2026-06-21 02:56:14 - tokenizer_training_rank_0 - INFO - === Training Configuration ===
# 2026-06-21 02:56:14 - tokenizer_training_rank_0 - INFO - Data path: data/US30_M30_ft.csv
# 2026-06-21 02:56:14 - tokenizer_training_rank_0 - INFO - Lookback window: 256
# 2026-06-21 02:56:14 - tokenizer_training_rank_0 - INFO - Predict window: 16
# 2026-06-21 02:56:14 - tokenizer_training_rank_0 - INFO - Batch size: 32
# 2026-06-21 02:56:14 - tokenizer_training_rank_0 - INFO - Learning rate: 0.0002
# 2026-06-21 02:56:14 - tokenizer_training_rank_0 - INFO - Training epochs: 8
# 2026-06-21 02:56:14 - tokenizer_training_rank_0 - INFO - Device: cuda:0
# 2026-06-21 02:56:14 - tokenizer_training_rank_0 - INFO - Distributed training: False
# 2026-06-21 02:56:14 - tokenizer_training_rank_0 - INFO - Starting tokenizer fine-tuning training...
# Starting tokenizer fine-tuning training...
# 2026-06-21 02:56:14 - tokenizer_training_rank_0 - INFO - Starting tokenizer training...
# Creating tokenizer training data loaders...
# Original data time range: 2025-06-22 22:00:00 to 2026-06-19 16:30:00
# Original data total length: 11755 records
# [TRAIN] Training set: first 8228 time points (0.7)
# [TRAIN] Training set time range: 2025-06-22 22:00:00 to 2026-03-04 13:30:00
# [TRAIN] Data length after split: 8228 records
# [TRAIN] Data length: 8228, Available samples: 7956
# Original data time range: 2025-06-22 22:00:00 to 2026-06-19 16:30:00
# Original data total length: 11755 records
# [VAL] Validation set: time points 8229 to 9991 (0.15)
# [VAL] Validation set time range: 2026-03-04 14:00:00 to 2026-04-28 04:30:00
# [VAL] Data length after split: 1763 records
# [VAL] Data length: 1763, Available samples: 1491
# Training set size: 7956, Validation set size: 1491
# 2026-06-21 02:56:26 - tokenizer_training_rank_0 - INFO - [Epoch 1/8, Step 50/248] LR: 0.000191, Loss: -0.0285
# [Epoch 1/8, Step 50/248] LR: 0.000191, Loss: -0.0285
# 2026-06-21 02:56:26 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0704
#   - Recon Loss Pre: 0.0085
#   - Recon Loss All: 0.0049
#   - VQ Loss: -0.0704
#   - Recon Loss Pre: 0.0085
#   - Recon Loss All: 0.0049
# 2026-06-21 02:56:34 - tokenizer_training_rank_0 - INFO - [Epoch 1/8, Step 100/248] LR: 0.000200, Loss: -0.0291
# [Epoch 1/8, Step 100/248] LR: 0.000200, Loss: -0.0291
# 2026-06-21 02:56:34 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0706
#   - Recon Loss Pre: 0.0078
#   - Recon Loss All: 0.0047
#   - VQ Loss: -0.0706
#   - Recon Loss Pre: 0.0078
#   - Recon Loss All: 0.0047
# 2026-06-21 02:56:43 - tokenizer_training_rank_0 - INFO - [Epoch 1/8, Step 150/248] LR: 0.000199, Loss: -0.0286
# [Epoch 1/8, Step 150/248] LR: 0.000199, Loss: -0.0286
# 2026-06-21 02:56:43 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0705
#   - Recon Loss Pre: 0.0086
#   - Recon Loss All: 0.0048
#   - VQ Loss: -0.0705
#   - Recon Loss Pre: 0.0086
#   - Recon Loss All: 0.0048
# 2026-06-21 02:56:51 - tokenizer_training_rank_0 - INFO - [Epoch 1/8, Step 200/248] LR: 0.000197, Loss: -0.0289
# [Epoch 1/8, Step 200/248] LR: 0.000197, Loss: -0.0289
# 2026-06-21 02:56:51 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0707
#   - Recon Loss Pre: 0.0082
#   - Recon Loss All: 0.0047
#   - VQ Loss: -0.0707
#   - Recon Loss Pre: 0.0082
#   - Recon Loss All: 0.0047
# 2026-06-21 02:57:03 - tokenizer_training_rank_0 - INFO -
# --- Epoch 1/8 Summary ---
# Validation Loss: 0.0051
# Epoch Time: 0:00:45
# Total Training Time: 0:00:45
#
#
# --- Epoch 1/8 Summary ---
# Validation Loss: 0.0051
# Epoch Time: 0:00:45
# Total Training Time: 0:00:45
#
# 2026-06-21 02:57:03 - tokenizer_training_rank_0 - INFO - Best model saved to: finetuned/US30_M30/tokenizer/best_model (validation loss: 0.0051)
# Best model saved to: finetuned/US30_M30/tokenizer/best_model (validation loss: 0.0051)
# 2026-06-21 02:57:03 - tokenizer_training_rank_0 - INFO - [Epoch 2/8, Step 2/248] LR: 0.000195, Loss: -0.0298
# [Epoch 2/8, Step 2/248] LR: 0.000195, Loss: -0.0298
# 2026-06-21 02:57:03 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0708
#   - Recon Loss Pre: 0.0069
#   - Recon Loss All: 0.0042
#   - VQ Loss: -0.0708
#   - Recon Loss Pre: 0.0069
#   - Recon Loss All: 0.0042
# 2026-06-21 02:57:12 - tokenizer_training_rank_0 - INFO - [Epoch 2/8, Step 52/248] LR: 0.000192, Loss: -0.0298
# [Epoch 2/8, Step 52/248] LR: 0.000192, Loss: -0.0298
# 2026-06-21 02:57:12 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0708
#   - Recon Loss Pre: 0.0071
#   - Recon Loss All: 0.0041
#   - VQ Loss: -0.0708
#   - Recon Loss Pre: 0.0071
#   - Recon Loss All: 0.0041
# 2026-06-21 02:57:21 - tokenizer_training_rank_0 - INFO - [Epoch 2/8, Step 102/248] LR: 0.000189, Loss: -0.0298
# [Epoch 2/8, Step 102/248] LR: 0.000189, Loss: -0.0298
# 2026-06-21 02:57:21 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0707
#   - Recon Loss Pre: 0.0070
#   - Recon Loss All: 0.0041
#   - VQ Loss: -0.0707
#   - Recon Loss Pre: 0.0070
#   - Recon Loss All: 0.0041
# 2026-06-21 02:57:30 - tokenizer_training_rank_0 - INFO - [Epoch 2/8, Step 152/248] LR: 0.000185, Loss: -0.0294
# [Epoch 2/8, Step 152/248] LR: 0.000185, Loss: -0.0294
# 2026-06-21 02:57:30 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0706
#   - Recon Loss Pre: 0.0074
#   - Recon Loss All: 0.0044
#   - VQ Loss: -0.0706
#   - Recon Loss Pre: 0.0074
#   - Recon Loss All: 0.0044
# 2026-06-21 02:57:39 - tokenizer_training_rank_0 - INFO - [Epoch 2/8, Step 202/248] LR: 0.000180, Loss: -0.0301
# [Epoch 2/8, Step 202/248] LR: 0.000180, Loss: -0.0301
# 2026-06-21 02:57:39 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0708
#   - Recon Loss Pre: 0.0068
#   - Recon Loss All: 0.0038
#   - VQ Loss: -0.0708
#   - Recon Loss Pre: 0.0068
#   - Recon Loss All: 0.0038
# 2026-06-21 02:57:50 - tokenizer_training_rank_0 - INFO -
# --- Epoch 2/8 Summary ---
# Validation Loss: 0.0052
# Epoch Time: 0:00:47
# Total Training Time: 0:00:47
#
#
# --- Epoch 2/8 Summary ---
# Validation Loss: 0.0052
# Epoch Time: 0:00:47
# Total Training Time: 0:00:47
#
# 2026-06-21 02:57:50 - tokenizer_training_rank_0 - INFO - [Epoch 3/8, Step 4/248] LR: 0.000175, Loss: -0.0296
# [Epoch 3/8, Step 4/248] LR: 0.000175, Loss: -0.0296
# 2026-06-21 02:57:51 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0708
#   - Recon Loss Pre: 0.0076
#   - Recon Loss All: 0.0039
#   - VQ Loss: -0.0708
#   - Recon Loss Pre: 0.0076
#   - Recon Loss All: 0.0039
# 2026-06-21 02:57:59 - tokenizer_training_rank_0 - INFO - [Epoch 3/8, Step 54/248] LR: 0.000170, Loss: -0.0301
# [Epoch 3/8, Step 54/248] LR: 0.000170, Loss: -0.0301
# 2026-06-21 02:57:59 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0709
#   - Recon Loss Pre: 0.0066
#   - Recon Loss All: 0.0040
#   - VQ Loss: -0.0709
#   - Recon Loss Pre: 0.0066
#   - Recon Loss All: 0.0040
# 2026-06-21 02:58:08 - tokenizer_training_rank_0 - INFO - [Epoch 3/8, Step 104/248] LR: 0.000163, Loss: -0.0301
# [Epoch 3/8, Step 104/248] LR: 0.000163, Loss: -0.0301
# 2026-06-21 02:58:08 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0708
#   - Recon Loss Pre: 0.0068
#   - Recon Loss All: 0.0039
#   - VQ Loss: -0.0708
#   - Recon Loss Pre: 0.0068
#   - Recon Loss All: 0.0039
# 2026-06-21 02:58:17 - tokenizer_training_rank_0 - INFO - [Epoch 3/8, Step 154/248] LR: 0.000157, Loss: -0.0304
# [Epoch 3/8, Step 154/248] LR: 0.000157, Loss: -0.0304
# 2026-06-21 02:58:17 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0064
#   - Recon Loss All: 0.0037
#   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0064
#   - Recon Loss All: 0.0037
# 2026-06-21 02:58:26 - tokenizer_training_rank_0 - INFO - [Epoch 3/8, Step 204/248] LR: 0.000150, Loss: -0.0302
# [Epoch 3/8, Step 204/248] LR: 0.000150, Loss: -0.0302
# 2026-06-21 02:58:26 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0067
#   - Recon Loss All: 0.0039
#   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0067
#   - Recon Loss All: 0.0039
# 2026-06-21 02:58:36 - tokenizer_training_rank_0 - INFO -
# --- Epoch 3/8 Summary ---
# Validation Loss: 0.0053
# Epoch Time: 0:00:46
# Total Training Time: 0:00:46
#
#
# --- Epoch 3/8 Summary ---
# Validation Loss: 0.0053
# Epoch Time: 0:00:46
# Total Training Time: 0:00:46
#
# 2026-06-21 02:58:38 - tokenizer_training_rank_0 - INFO - [Epoch 4/8, Step 6/248] LR: 0.000143, Loss: -0.0306
# [Epoch 4/8, Step 6/248] LR: 0.000143, Loss: -0.0306
# 2026-06-21 02:58:38 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0060
#   - Recon Loss All: 0.0037
#   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0060
#   - Recon Loss All: 0.0037
# 2026-06-21 02:58:46 - tokenizer_training_rank_0 - INFO - [Epoch 4/8, Step 56/248] LR: 0.000135, Loss: -0.0306
# [Epoch 4/8, Step 56/248] LR: 0.000135, Loss: -0.0306
# 2026-06-21 02:58:47 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0061
#   - Recon Loss All: 0.0037
#   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0061
#   - Recon Loss All: 0.0037
# 2026-06-21 02:58:55 - tokenizer_training_rank_0 - INFO - [Epoch 4/8, Step 106/248] LR: 0.000128, Loss: -0.0303
# [Epoch 4/8, Step 106/248] LR: 0.000128, Loss: -0.0303
# 2026-06-21 02:58:55 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0709
#   - Recon Loss Pre: 0.0066
#   - Recon Loss All: 0.0038
#   - VQ Loss: -0.0709
#   - Recon Loss Pre: 0.0066
#   - Recon Loss All: 0.0038
# 2026-06-21 02:59:04 - tokenizer_training_rank_0 - INFO - [Epoch 4/8, Step 156/248] LR: 0.000120, Loss: -0.0308
# [Epoch 4/8, Step 156/248] LR: 0.000120, Loss: -0.0308
# 2026-06-21 02:59:04 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0059
#   - Recon Loss All: 0.0035
#   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0059
#   - Recon Loss All: 0.0035
# 2026-06-21 02:59:13 - tokenizer_training_rank_0 - INFO - [Epoch 4/8, Step 206/248] LR: 0.000112, Loss: -0.0302
# [Epoch 4/8, Step 206/248] LR: 0.000112, Loss: -0.0302
# 2026-06-21 02:59:13 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0709
#   - Recon Loss Pre: 0.0064
#   - Recon Loss All: 0.0041
#   - VQ Loss: -0.0709
#   - Recon Loss Pre: 0.0064
#   - Recon Loss All: 0.0041
# 2026-06-21 02:59:23 - tokenizer_training_rank_0 - INFO -
# --- Epoch 4/8 Summary ---
# Validation Loss: 0.0053
# Epoch Time: 0:00:46
# Total Training Time: 0:00:46
#
#
# --- Epoch 4/8 Summary ---
# Validation Loss: 0.0053
# Epoch Time: 0:00:46
# Total Training Time: 0:00:46
#
# 2026-06-21 02:59:25 - tokenizer_training_rank_0 - INFO - [Epoch 5/8, Step 8/248] LR: 0.000103, Loss: -0.0307
# [Epoch 5/8, Step 8/248] LR: 0.000103, Loss: -0.0307
# 2026-06-21 02:59:25 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0059
#   - Recon Loss All: 0.0037
#   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0059
#   - Recon Loss All: 0.0037
# 2026-06-21 02:59:33 - tokenizer_training_rank_0 - INFO - [Epoch 5/8, Step 58/248] LR: 0.000095, Loss: -0.0310
# [Epoch 5/8, Step 58/248] LR: 0.000095, Loss: -0.0310
# 2026-06-21 02:59:34 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0711
#   - Recon Loss Pre: 0.0057
#   - Recon Loss All: 0.0034
#   - VQ Loss: -0.0711
#   - Recon Loss Pre: 0.0057
#   - Recon Loss All: 0.0034
# 2026-06-21 02:59:42 - tokenizer_training_rank_0 - INFO - [Epoch 5/8, Step 108/248] LR: 0.000087, Loss: -0.0302
# [Epoch 5/8, Step 108/248] LR: 0.000087, Loss: -0.0302
# 2026-06-21 02:59:42 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0709
#   - Recon Loss Pre: 0.0067
#   - Recon Loss All: 0.0039
#   - VQ Loss: -0.0709
#   - Recon Loss Pre: 0.0067
#   - Recon Loss All: 0.0039
# 2026-06-21 02:59:51 - tokenizer_training_rank_0 - INFO - [Epoch 5/8, Step 158/248] LR: 0.000079, Loss: -0.0310
# [Epoch 5/8, Step 158/248] LR: 0.000079, Loss: -0.0310
# 2026-06-21 02:59:51 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0711
#   - Recon Loss Pre: 0.0057
#   - Recon Loss All: 0.0035
#   - VQ Loss: -0.0711
#   - Recon Loss Pre: 0.0057
#   - Recon Loss All: 0.0035
# 2026-06-21 03:00:00 - tokenizer_training_rank_0 - INFO - [Epoch 5/8, Step 208/248] LR: 0.000071, Loss: -0.0303
# [Epoch 5/8, Step 208/248] LR: 0.000071, Loss: -0.0303
# 2026-06-21 03:00:00 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0066
#   - Recon Loss All: 0.0038
#   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0066
#   - Recon Loss All: 0.0038
# 2026-06-21 03:00:10 - tokenizer_training_rank_0 - INFO -
# --- Epoch 5/8 Summary ---
# Validation Loss: 0.0053
# Epoch Time: 0:00:46
# Total Training Time: 0:00:46
#
#
# --- Epoch 5/8 Summary ---
# Validation Loss: 0.0053
# Epoch Time: 0:00:46
# Total Training Time: 0:00:46
#
# 2026-06-21 03:00:12 - tokenizer_training_rank_0 - INFO - [Epoch 6/8, Step 10/248] LR: 0.000063, Loss: -0.0304
# [Epoch 6/8, Step 10/248] LR: 0.000063, Loss: -0.0304
# 2026-06-21 03:00:12 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0066
#   - Recon Loss All: 0.0038
#   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0066
#   - Recon Loss All: 0.0038
# 2026-06-21 03:00:20 - tokenizer_training_rank_0 - INFO - [Epoch 6/8, Step 60/248] LR: 0.000056, Loss: -0.0304
# [Epoch 6/8, Step 60/248] LR: 0.000056, Loss: -0.0304
# 2026-06-21 03:00:21 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0063
#   - Recon Loss All: 0.0040
#   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0063
#   - Recon Loss All: 0.0040
# 2026-06-21 03:00:29 - tokenizer_training_rank_0 - INFO - [Epoch 6/8, Step 110/248] LR: 0.000049, Loss: -0.0306
# [Epoch 6/8, Step 110/248] LR: 0.000049, Loss: -0.0306
# 2026-06-21 03:00:29 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0711
#   - Recon Loss Pre: 0.0062
#   - Recon Loss All: 0.0037
#   - VQ Loss: -0.0711
#   - Recon Loss Pre: 0.0062
#   - Recon Loss All: 0.0037
# 2026-06-21 03:00:38 - tokenizer_training_rank_0 - INFO - [Epoch 6/8, Step 160/248] LR: 0.000042, Loss: -0.0307
# [Epoch 6/8, Step 160/248] LR: 0.000042, Loss: -0.0307
# 2026-06-21 03:00:38 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0060
#   - Recon Loss All: 0.0036
#   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0060
#   - Recon Loss All: 0.0036
# 2026-06-21 03:00:47 - tokenizer_training_rank_0 - INFO - [Epoch 6/8, Step 210/248] LR: 0.000036, Loss: -0.0306
# [Epoch 6/8, Step 210/248] LR: 0.000036, Loss: -0.0306
# 2026-06-21 03:00:47 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0061
#   - Recon Loss All: 0.0037
#   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0061
#   - Recon Loss All: 0.0037
# 2026-06-21 03:00:57 - tokenizer_training_rank_0 - INFO -
# --- Epoch 6/8 Summary ---
# Validation Loss: 0.0053
# Epoch Time: 0:00:46
# Total Training Time: 0:00:46
#
#
# --- Epoch 6/8 Summary ---
# Validation Loss: 0.0053
# Epoch Time: 0:00:46
# Total Training Time: 0:00:46
#
# 2026-06-21 03:00:59 - tokenizer_training_rank_0 - INFO - [Epoch 7/8, Step 12/248] LR: 0.000030, Loss: -0.0308
# [Epoch 7/8, Step 12/248] LR: 0.000030, Loss: -0.0308
# 2026-06-21 03:00:59 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0711
#   - Recon Loss Pre: 0.0061
#   - Recon Loss All: 0.0034
#   - VQ Loss: -0.0711
#   - Recon Loss Pre: 0.0061
#   - Recon Loss All: 0.0034
# 2026-06-21 03:01:08 - tokenizer_training_rank_0 - INFO - [Epoch 7/8, Step 62/248] LR: 0.000024, Loss: -0.0305
# [Epoch 7/8, Step 62/248] LR: 0.000024, Loss: -0.0305
# 2026-06-21 03:01:08 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0062
#   - Recon Loss All: 0.0038
#   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0062
#   - Recon Loss All: 0.0038
# 2026-06-21 03:01:17 - tokenizer_training_rank_0 - INFO - [Epoch 7/8, Step 112/248] LR: 0.000019, Loss: -0.0303
# [Epoch 7/8, Step 112/248] LR: 0.000019, Loss: -0.0303
# 2026-06-21 03:01:17 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0711
#   - Recon Loss Pre: 0.0067
#   - Recon Loss All: 0.0038
#   - VQ Loss: -0.0711
#   - Recon Loss Pre: 0.0067
#   - Recon Loss All: 0.0038
# 2026-06-21 03:01:25 - tokenizer_training_rank_0 - INFO - [Epoch 7/8, Step 162/248] LR: 0.000014, Loss: -0.0304
# [Epoch 7/8, Step 162/248] LR: 0.000014, Loss: -0.0304
# 2026-06-21 03:01:26 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0711
#   - Recon Loss Pre: 0.0067
#   - Recon Loss All: 0.0036
#   - VQ Loss: -0.0711
#   - Recon Loss Pre: 0.0067
#   - Recon Loss All: 0.0036
# 2026-06-21 03:01:34 - tokenizer_training_rank_0 - INFO - [Epoch 7/8, Step 212/248] LR: 0.000010, Loss: -0.0307
# [Epoch 7/8, Step 212/248] LR: 0.000010, Loss: -0.0307
# 2026-06-21 03:01:34 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0711
#   - Recon Loss Pre: 0.0060
#   - Recon Loss All: 0.0036
#   - VQ Loss: -0.0711
#   - Recon Loss Pre: 0.0060
#   - Recon Loss All: 0.0036
# 2026-06-21 03:01:44 - tokenizer_training_rank_0 - INFO -
# --- Epoch 7/8 Summary ---
# Validation Loss: 0.0054
# Epoch Time: 0:00:46
# Total Training Time: 0:00:46
#
#
# --- Epoch 7/8 Summary ---
# Validation Loss: 0.0054
# Epoch Time: 0:00:46
# Total Training Time: 0:00:46
#
# 2026-06-21 03:01:46 - tokenizer_training_rank_0 - INFO - [Epoch 8/8, Step 14/248] LR: 0.000007, Loss: -0.0304
# [Epoch 8/8, Step 14/248] LR: 0.000007, Loss: -0.0304
# 2026-06-21 03:01:46 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0711
#   - Recon Loss Pre: 0.0067
#   - Recon Loss All: 0.0037
#   - VQ Loss: -0.0711
#   - Recon Loss Pre: 0.0067
#   - Recon Loss All: 0.0037
# 2026-06-21 03:01:55 - tokenizer_training_rank_0 - INFO - [Epoch 8/8, Step 64/248] LR: 0.000004, Loss: -0.0303
# [Epoch 8/8, Step 64/248] LR: 0.000004, Loss: -0.0303
# 2026-06-21 03:01:55 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0711
#   - Recon Loss Pre: 0.0069
#   - Recon Loss All: 0.0036
#   - VQ Loss: -0.0711
#   - Recon Loss Pre: 0.0069
#   - Recon Loss All: 0.0036
# 2026-06-21 03:02:04 - tokenizer_training_rank_0 - INFO - [Epoch 8/8, Step 114/248] LR: 0.000002, Loss: -0.0307
# [Epoch 8/8, Step 114/248] LR: 0.000002, Loss: -0.0307
# 2026-06-21 03:02:04 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0711
#   - Recon Loss Pre: 0.0062
#   - Recon Loss All: 0.0034
#   - VQ Loss: -0.0711
#   - Recon Loss Pre: 0.0062
#   - Recon Loss All: 0.0034
# 2026-06-21 03:02:13 - tokenizer_training_rank_0 - INFO - [Epoch 8/8, Step 164/248] LR: 0.000001, Loss: -0.0306
# [Epoch 8/8, Step 164/248] LR: 0.000001, Loss: -0.0306
# 2026-06-21 03:02:13 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0062
#   - Recon Loss All: 0.0037
#   - VQ Loss: -0.0710
#   - Recon Loss Pre: 0.0062
#   - Recon Loss All: 0.0037
# 2026-06-21 03:02:21 - tokenizer_training_rank_0 - INFO - [Epoch 8/8, Step 214/248] LR: 0.000000, Loss: -0.0309
# [Epoch 8/8, Step 214/248] LR: 0.000000, Loss: -0.0309
# 2026-06-21 03:02:21 - tokenizer_training_rank_0 - INFO -   - VQ Loss: -0.0712
#   - Recon Loss Pre: 0.0059
#   - Recon Loss All: 0.0035
#   - VQ Loss: -0.0712
#   - Recon Loss Pre: 0.0059
#   - Recon Loss All: 0.0035
# 2026-06-21 03:02:30 - tokenizer_training_rank_0 - INFO -
# --- Epoch 8/8 Summary ---
# Validation Loss: 0.0054
# Epoch Time: 0:00:46
# Total Training Time: 0:00:46
#
#
# --- Epoch 8/8 Summary ---
# Validation Loss: 0.0054
# Epoch Time: 0:00:46
# Total Training Time: 0:00:46
#
# 2026-06-21 03:02:30 - tokenizer_training_rank_0 - INFO - Tokenizer training completed! Best validation loss: 0.0051
# Training time: 6.26 minutes
# Model saved to: finetuned/US30_M30/tokenizer
#
# Tokenizer training completed! Best validation loss: 0.0051
# Training time: 6.26 minutes
# Model saved to: finetuned/US30_M30/tokenizer
#
# ============================================================
# Starting Basemodel Fine-tuning Phase
# ============================================================
# Tokenizer model exists: True
# Basemodel model exists: True
# 2026-06-21 03:02:30 - basemodel_training_rank_0 - INFO - === Basemodel Training Started ===
# 2026-06-21 03:02:30 - basemodel_training_rank_0 - INFO - Experiment Name: US30_M30
# 2026-06-21 03:02:30 - basemodel_training_rank_0 - INFO - Log Directory: finetuned/US30_M30/logs
# 2026-06-21 03:02:30 - basemodel_training_rank_0 - INFO - Rank: 0
# 2026-06-21 03:02:30 - basemodel_training_rank_0 - INFO - Timestamp: 2026-06-21 03:02:30
# 2026-06-21 03:02:30 - basemodel_training_rank_0 - INFO - Loading fine-tuned tokenizer...
# Loading fine-tuned tokenizer...
# Loading weights from local directory
# 2026-06-21 03:02:30 - basemodel_training_rank_0 - INFO - Loading pretrained predictor...
# Loading pretrained predictor...
# 2026-06-21 03:02:31 - basemodel_training_rank_0 - INFO - Model parameters: 24,741,376
# Model parameters: 24,741,376
# 2026-06-21 03:02:31 - basemodel_training_rank_0 - INFO - === Training Configuration ===
# 2026-06-21 03:02:31 - basemodel_training_rank_0 - INFO - Data path: data/US30_M30_ft.csv
# 2026-06-21 03:02:31 - basemodel_training_rank_0 - INFO - Lookback window: 256
# 2026-06-21 03:02:31 - basemodel_training_rank_0 - INFO - Predict window: 16
# 2026-06-21 03:02:31 - basemodel_training_rank_0 - INFO - Batch size: 32
# 2026-06-21 03:02:31 - basemodel_training_rank_0 - INFO - Learning rate: 2e-05
# 2026-06-21 03:02:31 - basemodel_training_rank_0 - INFO - Training epochs: 15
# 2026-06-21 03:02:31 - basemodel_training_rank_0 - INFO - Device: cuda:0
# 2026-06-21 03:02:31 - basemodel_training_rank_0 - INFO - Tokenizer path: finetuned/US30_M30/tokenizer/best_model
# 2026-06-21 03:02:31 - basemodel_training_rank_0 - INFO - Pretrained model path: NeoQuasar/Kronos-small
# 2026-06-21 03:02:31 - basemodel_training_rank_0 - INFO - Starting fine-tuning training...
# Starting fine-tuning training...
# 2026-06-21 03:02:31 - basemodel_training_rank_0 - INFO - Starting training...
# Creating data loaders...
# Original data time range: 2025-06-22 22:00:00 to 2026-06-19 16:30:00
# Original data total length: 11755 records
# [TRAIN] Training set: first 8228 time points (0.7)
# [TRAIN] Training set time range: 2025-06-22 22:00:00 to 2026-03-04 13:30:00
# [TRAIN] Data length after split: 8228 records
# [TRAIN] Data length: 8228, Available samples: 7956
# Original data time range: 2025-06-22 22:00:00 to 2026-06-19 16:30:00
# Original data total length: 11755 records
# [VAL] Validation set: time points 8229 to 9991 (0.15)
# [VAL] Validation set time range: 2026-03-04 14:00:00 to 2026-04-28 04:30:00
# [VAL] Data length after split: 1763 records
# [VAL] Data length: 1763, Available samples: 1491
# Training set size: 7956, Validation set size: 1491
# 2026-06-21 03:02:57 - basemodel_training_rank_0 - INFO - [Epoch 1/15, Step 50/248] LR: 0.000010, Loss: 2.2919
# [Epoch 1/15, Step 50/248] LR: 0.000010, Loss: 2.2919
# 2026-06-21 03:03:23 - basemodel_training_rank_0 - INFO - [Epoch 1/15, Step 100/248] LR: 0.000020, Loss: 2.1070
# [Epoch 1/15, Step 100/248] LR: 0.000020, Loss: 2.1070
# 2026-06-21 03:03:50 - basemodel_training_rank_0 - INFO - [Epoch 1/15, Step 150/248] LR: 0.000020, Loss: 1.9998
# [Epoch 1/15, Step 150/248] LR: 0.000020, Loss: 1.9998
# 2026-06-21 03:04:16 - basemodel_training_rank_0 - INFO - [Epoch 1/15, Step 200/248] LR: 0.000020, Loss: 1.9281
# [Epoch 1/15, Step 200/248] LR: 0.000020, Loss: 1.9281
# 2026-06-21 03:04:49 - basemodel_training_rank_0 - INFO -
# --- Epoch 1/15 Summary ---
# Training Loss: 2.0394
# Validation Loss: 2.1007
# Epoch Time: 138.44 seconds
#
#
# --- Epoch 1/15 Summary ---
# Training Loss: 2.0394
# Validation Loss: 2.1007
# Epoch Time: 138.44 seconds
#
# 2026-06-21 03:04:50 - basemodel_training_rank_0 - INFO - Best model saved to: finetuned/US30_M30/basemodel/best_model (validation loss: 2.1007)
# Best model saved to: finetuned/US30_M30/basemodel/best_model (validation loss: 2.1007)

# %% [markdown]
# ## Bước 4 — Đo edge: model FINE-TUNED vs GỐC (out-of-sample)
#
# So sánh trên **phần đuôi dữ liệu chưa train** (last 2000 nến). Nếu fine-tune có tác dụng, model mới phải có **accuracy / IC cao hơn** model gốc.

# %%
DATA = f'trading/mydata/{SYM}_M30.csv'
FT_MODEL = f'finetune_csv/finetuned/{SYM}_M30/basemodel/best_model'
FT_TOK   = f'finetune_csv/finetuned/{SYM}_M30/tokenizer/best_model'
COMMON = '--lookback 256 --pred-len 6 --horizon 3 --signal-every 8 --last-n 2000 --ensemble 5'

base_cmd = ('python -m trading.measure_edge_all --predictor kronos '
            '--model NeoQuasar/Kronos-small --tokenizer NeoQuasar/Kronos-Tokenizer-base '
            f'{COMMON} --csv {DATA}')
ft_cmd = ('python -m trading.measure_edge_all --predictor kronos '
          f'--model {FT_MODEL} --tokenizer {FT_TOK} {COMMON} --csv {DATA}')

print('===== MODEL GỐC (base Kronos-small) =====')
# !{base_cmd}
print('\n===== MODEL FINE-TUNED =====')
# !{ft_cmd}

# %% [markdown]
# ## Bước 5 — Diễn giải & bước tiếp
#
# - **Fine-tune thành công** = model mới có **accuracy cao hơn rõ** (vd 53–55%+), IC/RankIC dương hơn model gốc, trên phần out-of-sample.
# - **Không cải thiện?** Thử: tăng `basemodel_epochs`, đổi `predictor_learning_rate` (vd 5e-5), giảm `predict_window`, hoặc dùng nhiều dữ liệu hơn (mã có lịch sử dài như XAUUSD 87k nến).
# - **Cẩn thận overfit:** đây là dữ liệu nhỏ (~11k nến). Edge out-of-sample mới đáng tin; đừng nhìn loss train.
# - **Có edge rồi?** Quay lại notebook `trading/Kronos_Trading_Colab.ipynb`, đặt `MODEL_NAME` = đường dẫn model fine-tuned để backtest có SL/TP/sizing đầy đủ.
#
# > Lưu ý: muốn chỉ fine-tune predictor (nhanh hơn, an toàn hơn với dữ liệu nhỏ), thêm `--skip-tokenizer` vào lệnh ở Bước 3 — nhưng khi đó cần tokenizer gốc; hỏi mình để chỉnh config cho đúng.
